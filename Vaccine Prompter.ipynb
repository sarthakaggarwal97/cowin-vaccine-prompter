# %%
# !pip install fake-useragent
# Out:
# Collecting fake-useragent
#   Downloading https://files.pythonhosted.org/packages/d1/79/af647635d6968e2deb57a208d309f6069d31cb138066d7e821e575112a80/fake-useragent-0.1.11.tar.gz
# Building wheels for collected packages: fake-useragent
#   Building wheel for fake-useragent (setup.py): started
#   Building wheel for fake-useragent (setup.py): finished with status 'done'
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-cp37-none-any.whl size=13490 sha256=776311d04981b604d8a644d1662138e89f6eabe680f6b8132aa1ce32189fd61a
#   Stored in directory: C:\Users\hp\AppData\Local\pip\Cache\wheels\5e\63\09\d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
# Successfully built fake-useragent
# Installing collected packages: fake-useragent
# Successfully installed fake-useragent-0.1.11

# %%
import requests
from fake_useragent import UserAgent
import json
import pandas as pd
from datetime import datetime, timedelta

# %%
pincode = '110068'
date = '16-05-2021'
request_url = "https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/findByPin?pincode={}&date={}".format(pincode, date)
temp_user_agent = UserAgent()
browser_header = {'User-Agent': temp_user_agent.random}

# %%
response = requests.get(request_url, headers=browser_header)
resp_json = json.loads(response.text)['sessions']
resp_json
# Out:
# [{'center_id': 697818,
#   'name': 'SDMC SCHOOL MAIDAN GARHI SITE4',
#   'address': 'SDMC SCHOOL MAIDAN GARHI',
#   'state_name': 'Delhi',
#   'district_name': 'South Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110068,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'lat': 28,
#   'long': 77,
#   'fee_type': 'Free',
#   'session_id': '4ad844f7-6151-409f-afb4-07976d87b369',
#   'date': '16-05-2021',
#   'available_capacity_dose1': 0,
#   'available_capacity_dose2': 4,
#   'available_capacity': 4,
#   'fee': '0',
#   'min_age_limit': 18,
#   'vaccine': 'COVISHIELD',
#   'slots': ['09:00AM-11:00AM',
#    '11:00AM-01:00PM',
#    '01:00PM-03:00PM',
#    '03:00PM-05:00PM']},
#  {'center_id': 701439,
#   'name': 'SDMC SCHOOL MAIDAN GARHI SITE5',
#   'address': 'SDMC SCHOOL MAIDAN GARHI',
#   'state_name': 'Delhi',
#   'district_name': 'South Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110068,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'lat': 28,
#   'long': 77,
#   'fee_type': 'Free',
#   'session_id': '8d6db88f-bc71-4788-82b0-f5ddf1617bb6',
#   'date': '16-05-2021',
#   'available_capacity_dose1': 0,
#   'available_capacity_dose2': 2,
#   'available_capacity': 2,
#   'fee': '0',
#   'min_age_limit': 18,
#   'vaccine': 'COVISHIELD',
#   'slots': ['09:00AM-11:00AM',
#    '11:00AM-01:00PM',
#    '01:00PM-03:00PM',
#    '03:00PM-05:00PM']},
#  {'center_id': 697811,
#   'name': 'SDMC SCHOOL MAIDAN GARHI SITE1',
#   'address': 'SDMC SCHOOL MAIDAN GARHI',
#   'state_name': 'Delhi',
#   'district_name': 'South Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110068,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'lat': 28,
#   'long': 77,
#   'fee_type': 'Free',
#   'session_id': 'fc1e3e8f-bc1a-4cee-a3b4-a1dcf15bdc53',
#   'date': '16-05-2021',
#   'available_capacity_dose1': 0,
#   'available_capacity_dose2': 3,
#   'available_capacity': 3,
#   'fee': '0',
#   'min_age_limit': 18,
#   'vaccine': 'COVISHIELD',
#   'slots': ['09:00AM-11:00AM',
#    '11:00AM-01:00PM',
#    '01:00PM-03:00PM',
#    '03:00PM-05:00PM']},
#  {'center_id': 697814,
#   'name': 'SDMC SCHOOL MAIDAN GARHI SITE2',
#   'address': 'SDMC SCHOOL MAIDAN GARHI',
#   'state_name': 'Delhi',
#   'district_name': 'South Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110068,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'lat': 28,
#   'long': 77,
#   'fee_type': 'Free',
#   'session_id': 'a0feb3b2-e9c4-4948-af7f-d39ef3d76ef4',
#   'date': '16-05-2021',
#   'available_capacity_dose1': 0,
#   'available_capacity_dose2': 8,
#   'available_capacity': 8,
#   'fee': '0',
#   'min_age_limit': 18,
#   'vaccine': 'COVISHIELD',
#   'slots': ['09:00AM-11:00AM',
#    '11:00AM-01:00PM',
#    '01:00PM-03:00PM',
#    '03:00PM-05:00PM']},
#  {'center_id': 697817,
#   'name': 'SDMC SCHOOL MAIDAN GARHI SITE3',
#   'address': 'SDMC SCHOOL MAIDAN GARHI',
#   'state_name': 'Delhi',
#   'district_name': 'South Delhi',
#   'block_name': 'Not Applicable',
#   'pincode': 110068,
#   'from': '09:00:00',
#   'to': '17:00:00',
#   'lat': 28,
#   'long': 77,
#   'fee_type': 'Free',
#   'session_id': '5aa9a560-0f37-4b66-9cb7-b97649584cc4',
#   'date': '16-05-2021',
#   'available_capacity_dose1': 0,
#   'available_capacity_dose2': 5,
#   'available_capacity': 5,
#   'fee': '0',
#   'min_age_limit': 18,
#   'vaccine': 'COVISHIELD',
#   'slots': ['09:00AM-11:00AM',
#    '11:00AM-01:00PM',
#    '01:00PM-03:00PM',
#    '03:00PM-05:00PM']}]

# %%
df = pd.DataFrame(resp_json)
df
# Out:
#    center_id                            name                   address  \
# 0     697818  SDMC SCHOOL MAIDAN GARHI SITE4  SDMC SCHOOL MAIDAN GARHI
# 1     701439  SDMC SCHOOL MAIDAN GARHI SITE5  SDMC SCHOOL MAIDAN GARHI
# 2     697811  SDMC SCHOOL MAIDAN GARHI SITE1  SDMC SCHOOL MAIDAN GARHI
# 3     697814  SDMC SCHOOL MAIDAN GARHI SITE2  SDMC SCHOOL MAIDAN GARHI
# 4     697817  SDMC SCHOOL MAIDAN GARHI SITE3  SDMC SCHOOL MAIDAN GARHI
#
#   state_name district_name      block_name  pincode      from        to  lat  \
# 0      Delhi   South Delhi  Not Applicable   110068  09:00:00  17:00:00   28
# 1      Delhi   South Delhi  Not Applicable   110068  09:00:00  17:00:00   28
# 2      Delhi   South Delhi  Not Applicable   110068  09:00:00  17:00:00   28
# 3      Delhi   South Delhi  Not Applicable   110068  09:00:00  17:00:00   28
# 4      Delhi   South Delhi  Not Applicable   110068  09:00:00  17:00:00   28
#
#    ...  fee_type                            session_id        date  \
# 0  ...      Free  4ad844f7-6151-409f-afb4-07976d87b369  16-05-2021
# 1  ...      Free  8d6db88f-bc71-4788-82b0-f5ddf1617bb6  16-05-2021
# 2  ...      Free  fc1e3e8f-bc1a-4cee-a3b4-a1dcf15bdc53  16-05-2021
# 3  ...      Free  a0feb3b2-e9c4-4948-af7f-d39ef3d76ef4  16-05-2021
# 4  ...      Free  5aa9a560-0f37-4b66-9cb7-b97649584cc4  16-05-2021
#
#   available_capacity_dose1  available_capacity_dose2  available_capacity  fee  \
# 0                        0                         4                   4    0
# 1                        0                         2                   2    0
# 2                        0                         3                   3    0
# 3                        0                         8                   8    0
# 4                        0                         5                   5    0
#
#   min_age_limit     vaccine                                              slots
# 0            18  COVISHIELD  [09:00AM-11:00AM, 11:00AM-01:00PM, 01:00PM-03:...
# 1            18  COVISHIELD  [09:00AM-11:00AM, 11:00AM-01:00PM, 01:00PM-03:...
# 2            18  COVISHIELD  [09:00AM-11:00AM, 11:00AM-01:00PM, 01:00PM-03:...
# 3            18  COVISHIELD  [09:00AM-11:00AM, 11:00AM-01:00PM, 01:00PM-03:...
# 4            18  COVISHIELD  [09:00AM-11:00AM, 11:00AM-01:00PM, 01:00PM-03:...
#
# [5 rows x 21 columns]

# %%
df['available_capacity_dose1']
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: available_capacity_dose1, dtype: int64

# %%
# TO GET THE STATE ID
# https://cdn-api.co-vin.in/api/v2/admin/location/states


# TO GET THE DISTRICT ID
# https://cdn-api.co-vin.in/api/v2/admin/location/districts/{state_id}

# %%
def check_availibilty(sc):
    
    temp_user_agent = UserAgent()
    browser_header = {'User-Agent': temp_user_agent.random}
    
    presentday = datetime.now()
    tomorrow = presentday + timedelta(1)
    pincode = '110018'
    district_id = '150'
    date = tomorrow.strftime('%d-%m-%Y')
    print("looping for date {}".format(date))
    
    request_url_pincode = "https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/findByPin?pincode={}&date={}".format(pincode, date)
    request_url_disrict_id = "https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/findByDistrict?district_id={}&date={}".format(district_id, date)
    
    
    response = requests.get(request_url_disrict_id, headers=browser_header)
    resp_json = json.loads(response.text)['sessions']
    
    df = pd.DataFrame(resp_json)
    df_min_age_limit = df['min_age_limit']
    df_availabilty = df['available_capacity_dose1']
    for key, value in df_availabilty.iteritems():
        if df_min_age_limit[key] == 18 and value > 0:
            print(key, value)
            # Might as well play a song :p
    
    s.enter(4, 1, check_availibilty, (sc,))

# %%
import sched, time
s = sched.scheduler(time.time, time.sleep)
s.enter(0, 1, check_availibilty, (s,))
s.run()
# Out:
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
# looping for date 17-05-2021
